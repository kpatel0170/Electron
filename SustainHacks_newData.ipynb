# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.listdir("./Us_data"))
# Out:
# ['AEP_hourly.csv', 'Combinedfiles.csv', 'COMED_hourly.csv', 'DAYTON_hourly.csv', 'DEOK_hourly.csv', 'DOM_hourly.csv', 'DUQ_hourly.csv', 'EKPC_hourly.csv', 'est_hourly.paruqet', 'FE_hourly.csv', 'finaldata.csv', 'NI_hourly.csv', 'PJME_hourly.csv', 'PJMW_hourly.csv', 'pjm_hourly_est.csv', 'PJM_Load_hourly.csv', 'tryingsomething.csv']

# %%
dt = pd.read_csv("./Us_data/.csv")
dt
# Out:
#          Unnamed: 0             Datetime   AEP_MW  COMED_MW  DAYTON_MW  \
# 0                 0  2004-12-31 01:00:00  13478.0       NaN        NaN
# 1                 1  2004-12-31 02:00:00  12865.0       NaN        NaN
# 2                 2  2004-12-31 03:00:00  12577.0       NaN        NaN
# 3                 3  2004-12-31 04:00:00  12517.0       NaN        NaN
# 4                 4  2004-12-31 05:00:00  12670.0       NaN        NaN
# ...             ...                  ...      ...       ...        ...
# 1268424     1268424  2001-01-01 20:00:00      NaN       NaN        NaN
# 1268425     1268425  2001-01-01 21:00:00      NaN       NaN        NaN
# 1268426     1268426  2001-01-01 22:00:00      NaN       NaN        NaN
# 1268427     1268427  2001-01-01 23:00:00      NaN       NaN        NaN
# 1268428     1268428  2001-01-02 00:00:00      NaN       NaN        NaN
#
#          DEOK_MW  DOM_MW  DUQ_MW  EKPC_MW  FE_MW  ...  DEOK  DOM  DUQ  EKPC  \
# ...

# %%
dt2 = pd.read_csv("./Us_data/COMED_hourly.csv")
dt
# Out:
#        Unnamed: 0.12  Unnamed: 0.11  Unnamed: 0.10  Unnamed: 0.9  \
# 0              54778          54778          54778         54778
# 1              54779          54779          54779         54779
# 2              54780          54780          54780         54780
# 3              54781          54781          54781         54781
# 4              54782          54782          54782         54782
# ...              ...            ...            ...           ...
# 74676         129454         129454         125358        123310
# 74677         129455         129455         125359        123311
# 74678         129456         129456         125360        123312
# 74679         129457         129457         125361        123313
# 74680         129458         129458         125362        123314
#
#        Unnamed: 0.8  Unnamed: 0.7  Unnamed: 0.6  Unnamed: 0.5  Unnamed: 0.4  \
# 0             54778       54778.0       54778.0       54778.0       54778.0
# ...
